# %%
import pandas as pd

cars = pd.Series(['BMW','Tesla','Mercedes','Porche'])
cars
# Out:
# 0         BMW
# 1       Tesla
# 2    Mercedes
# 3      Porche
# dtype: object

# %%
colors = pd.Series(['Red','Blue','Black'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    Black
# dtype: object

# %%
cars = pd.DataFrame({'Make':cars,'Color':colors})
cars
# Out:
#        Make  Color
# 0       BMW    Red
# 1     Tesla   Blue
# 2  Mercedes  Black
# 3    Porche    NaN

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2024-12-07 08:19:20--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv.1’
#
# car-sales.csv.1     100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-12-07 08:19:20 (26.1 MB/s) - ‘car-sales.csv.1’ saved [369/369]

# %%
df = pd.read_csv("car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df[['Make','Colour']]
# Out:
#      Make Colour
# 0  Toyota  White
# 1   Honda    Red
# 2  Toyota   Blue
# 3     BMW  Black
# 4  Nissan  White
# 5  Toyota  Green
# 6   Honda   Blue
# 7   Honda   Blue
# 8  Toyota  White
# 9  Nissan  White

# %%
df[(df['Make']=='Toyota') | (df['Odometer (KM)']<70000)]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
df.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %%
df['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
df['odemeter (Mile)'] = df['Odometer (KM)'] / 1.6
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  odemeter (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
df['Odometer  (Mile)']=df['Odometer (KM)'].apply(lambda x:x/1.6)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000
#
#    Odometer  (Mile)
# 0         93776.875
# 1         54936.875
# 2         20343.125
# 3          6986.875
# 4        133184.375
# 5         62008.125
# 6         28561.250
# 7         34211.250
# 8         37500.000
# ...

# %%
def currency(x):
    if '$' in x:
        return 'USD'
    else:
        return'unknown'
df['Currency'] = df ['Price'].apply(currency)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# ...

# %%
df.drop([1,3,9],axis=0)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4  $4,000.00        93776.875
# 2  Toyota   Blue          32549      3  $7,000.00        20343.125
# 4  Nissan  White         213095      4  $3,500.00       133184.375
# 5  Toyota  Green          99213      4  $4,500.00        62008.125
# 6   Honda   Blue          45698      4  $7,500.00        28561.250
# 7   Honda   Blue          54738      4  $7,000.00        34211.250
# 8  Toyota  White          60000      4  $6,250.00        37500.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 2         20343.125      USD
# 4        133184.375      USD
# 5         62008.125      USD
# 6         28561.250      USD
# 7         34211.250      USD
# 8         37500.000      USD

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# ...

# %%
df.dtypes
# Out:
# Make                 object
# Colour               object
# Odometer (KM)         int64
# Doors                 int64
# Price                object
# odemeter (Mile)     float64
# Odometer  (Mile)    float64
# Currency             object
# dtype: object

# %%
df['Price']=df['Price'].str.replace('[/$/./,]','',regex=True)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   400000        93776.875
# 1   Honda    Red          87899      4   500000        54936.875
# 2  Toyota   Blue          32549      3   700000        20343.125
# 3     BMW  Black          11179      5  2200000         6986.875
# 4  Nissan  White         213095      4   350000       133184.375
# 5  Toyota  Green          99213      4   450000        62008.125
# 6   Honda   Blue          45698      4   750000        28561.250
# 7   Honda   Blue          54738      4   700000        34211.250
# 8  Toyota  White          60000      4   625000        37500.000
# 9  Nissan  White          31600      4   970000        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# 6         28561.250      USD
# ...

# %%
df['Price']=df['Price'].astype(int)
df.dtypes
# Out:
# Make                 object
# Colour               object
# Odometer (KM)         int64
# Doors                 int64
# Price                 int64
# odemeter (Mile)     float64
# Odometer  (Mile)    float64
# Currency             object
# dtype: object

# %%
df['Price']=df['Price']/100
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   4000.0        93776.875
# 1   Honda    Red          87899      4   5000.0        54936.875
# 2  Toyota   Blue          32549      3   7000.0        20343.125
# 3     BMW  Black          11179      5  22000.0         6986.875
# 4  Nissan  White         213095      4   3500.0       133184.375
# 5  Toyota  Green          99213      4   4500.0        62008.125
# 6   Honda   Blue          45698      4   7500.0        28561.250
# 7   Honda   Blue          54738      4   7000.0        34211.250
# 8  Toyota  White          60000      4   6250.0        37500.000
# 9  Nissan  White          31600      4   9700.0        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# 6         28561.250      USD
# ...

# %%
df_copy = df.copy()
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   4000.0        93776.875
# 1   Honda    Red          87899      4   5000.0        54936.875
# 2  Toyota   Blue          32549      3   7000.0        20343.125
# 3     BMW  Black          11179      5  22000.0         6986.875
# 4  Nissan  White         213095      4   3500.0       133184.375
# 5  Toyota  Green          99213      4   4500.0        62008.125
# 6   Honda   Blue          45698      4   7500.0        28561.250
# 7   Honda   Blue          54738      4   7000.0        34211.250
# 8  Toyota  White          60000      4   6250.0        37500.000
# 9  Nissan  White          31600      4   9700.0        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# 6         28561.250      USD
# ...

# %%
df.to_csv("car_sales_processed.csv")

# %%
df.to_excel("car_sales_processed.xlsx")

# %%
df.drop_duplicates()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 0  Toyota  White         150043      4   4000.0        93776.875
# 1   Honda    Red          87899      4   5000.0        54936.875
# 2  Toyota   Blue          32549      3   7000.0        20343.125
# 3     BMW  Black          11179      5  22000.0         6986.875
# 4  Nissan  White         213095      4   3500.0       133184.375
# 5  Toyota  Green          99213      4   4500.0        62008.125
# 6   Honda   Blue          45698      4   7500.0        28561.250
# 7   Honda   Blue          54738      4   7000.0        34211.250
# 8  Toyota  White          60000      4   6250.0        37500.000
# 9  Nissan  White          31600      4   9700.0        19750.000
#
#    Odometer  (Mile) Currency
# 0         93776.875      USD
# 1         54936.875      USD
# 2         20343.125      USD
# 3          6986.875      USD
# 4        133184.375      USD
# 5         62008.125      USD
# 6         28561.250      USD
# ...

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Out:
# --2024-12-07 08:19:22--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-12-07 08:19:22 (4.86 MB/s) - ‘car-sales-missing-data.csv’ saved [287/287]

# %%
car_sales_missing = pd.read_csv("/content/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.dropna(subset = ['Price'],inplace=True)
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].mean()
# Out:
# 98763.2

# %%
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),inplace=True)
# Out:
# <ipython-input-61-728e782be5ee>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),inplace=True)

# %%
car_sales_missing["Colour"]=car_sales_missing["Colour"].fillna(car_sales_missing["Colour"].mode()[0])

car_sales_missing["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6    White
# 9    White
# Name: Colour, dtype: object

# %%
df.sort_values(by="Price",ascending= False).reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 0     BMW  Black          11179      5  22000.0         6986.875
# 1  Nissan  White          31600      4   9700.0        19750.000
# 2   Honda   Blue          45698      4   7500.0        28561.250
# 3  Toyota   Blue          32549      3   7000.0        20343.125
# 4   Honda   Blue          54738      4   7000.0        34211.250
# 5  Toyota  White          60000      4   6250.0        37500.000
# 6   Honda    Red          87899      4   5000.0        54936.875
# 7  Toyota  Green          99213      4   4500.0        62008.125
# 8  Toyota  White         150043      4   4000.0        93776.875
# 9  Nissan  White         213095      4   3500.0       133184.375
#
#    Odometer  (Mile) Currency
# 0          6986.875      USD
# 1         19750.000      USD
# 2         28561.250      USD
# 3         20343.125      USD
# 4         34211.250      USD
# 5         37500.000      USD
# 6         54936.875      USD
# ...

# %%
df.sample(frac = 1.0)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  odemeter (Mile)  \
# 2  Toyota   Blue          32549      3   7000.0        20343.125
# 3     BMW  Black          11179      5  22000.0         6986.875
# 1   Honda    Red          87899      4   5000.0        54936.875
# 7   Honda   Blue          54738      4   7000.0        34211.250
# 9  Nissan  White          31600      4   9700.0        19750.000
# 5  Toyota  Green          99213      4   4500.0        62008.125
# 0  Toyota  White         150043      4   4000.0        93776.875
# 6   Honda   Blue          45698      4   7500.0        28561.250
# 4  Nissan  White         213095      4   3500.0       133184.375
# 8  Toyota  White          60000      4   6250.0        37500.000
#
#    Odometer  (Mile) Currency
# 2         20343.125      USD
# 3          6986.875      USD
# 1         54936.875      USD
# 7         34211.250      USD
# 9         19750.000      USD
# 5         62008.125      USD
# 0         93776.875      USD
# ...
