# %%
import matplotlib.pyplot as plt
import numpy  as np
import pandas as pd

# %%
#2 Create a simple plot using plt.plot()

arr=[2,3,4,5,6,7,8]
arr2=[3,4,6,7,8,9,10]
plt.plot(arr,arr2)
plt.show()

# %%
# 5 Plot X & y (the lists you've created)

plt.plot(arr,arr2)
plt.show()

# %%
#6 Create a plot using plt.subplots()
fig,axs =plt.subplots(2,3)
axs[0,2].plot(arr,arr2);
axs[0,0].scatter(arr,arr2);
plt.savefig('test.png')

# %%
#10 Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X

# %%
# 10 Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
Y=np.linspace(0,100,10)
fig,axs = plt.subplots(2,2)
axs[0,0].plot(Y,Y**2)
axs[0,1].scatter(Y,np.exp(Y))
axs[1,0].plot(Y,np.sin(Y))
axs[1,1].plot(Y,Y**5);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Prepare data (create two lists of 5 numbers, X & y)
X = [34, 77, 21, 54, 9]
y = [9, 45, 89, 66, 4]

# Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Add data (X, y) to axes
ax.plot(X, y)

# Customize plot by adding a title, xlabel and ylabel
ax.set(title="Sample simple plot",
       xlabel="x-axis",
       ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'Sample simple plot'),
#  Text(0.5, 0, 'x-axis'),
#  Text(0, 0.5, 'y-axis')]

# %%
# Create a NumPy array of 1000 random numbers and save it to X
X = np.random.random(1000)

# Create a histogram plot of X
fig, ax = plt.subplots()
ax.hist(X)
# Out:
# (array([ 95.,  98.,  93.,  87., 102., 110., 105.,  99., 112.,  99.]),
#  array([0.00230002, 0.10189589, 0.20149175, 0.30108762, 0.40068349,
#         0.50027935, 0.59987522, 0.69947109, 0.79906695, 0.89866282,
#         0.99825869]),
#  <BarContainer object of 10 artists>)
